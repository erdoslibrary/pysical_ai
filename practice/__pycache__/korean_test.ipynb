# %% [markdown]
# # bash 명령어
# sudo apt-get update \
# sudo apt-get install -y fonts-nanum \
# sudo fc-cache -fv

# %%
import matplotlib
print(matplotlib.__file__)
# Out:
# /home/erdos/Downloads/workspace/robot_project/.venv/lib/python3.10/site-packages/matplotlib/__init__.py

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

# 1. 시스템에 설치된 나눔고딕 경로 설정
# 보통 우분투의 경우 아래 경로에 설치됩니다.
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# 2. 폰트 이름 추출 및 설정
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# 3. 마이너스 깨짐 방지
mpl.rcParams['axes.unicode_minus'] = False

# 테스트 실행
plt.text(0.5, 0.5, '한글 테스트 성공', size=20, ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 폰트 설정
plt.rcParams["font.family"] = 'NanumGothic'
mpl.rcParams['axes.unicode_minus'] = False  # 마이너스 폰트 깨짐 방지

# 예시 그래프
plt.figure(figsize=(8, 6))
plt.plot([1, 2, 3, 4], [10, 20, 25, 30])
plt.title('예제 그래프')
plt.xlabel('X 축')
plt.ylabel('Y 축')
plt.show()
